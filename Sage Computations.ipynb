# %% [markdown]
# # Polynomials over Finite Fields

# %%
#Generates the finite field of 5 elements
k = GF(5**2)

#Generates a finite field of 5 elements except a generator is specified
l.<a> = FiniteField(3**3)

#Useful functions:
    # order(k): outputs the order of k
    # charpoly(x, var='x'): returns the characteristic polynomial from the field extension
        
        #sage: k.<alpha> = GF(7^10); k
        #Finite Field in alpha of size 7^10
        #sage: alpha.charpoly('T')
        #T^10 + T^6 + T^5 + 4*T^4 + T^3 + 2*T^2 + 3*T + 3
        #sage: characteristic_polynomial(alpha, 'T')
        #T^10 + T^6 + T^5 + 4*T^4 + T^3 + 2*T^2 + 3*T + 3
        
    # enumerate(k): enumerates the elements of the field
        
#Ways to generate a polynomial ring with indeterminant x
R = PolynomialRing(k, 'x')

#Generates a list that corresponds to the elements of the finite field
def lstmaker(k):
    
    lst = []
    
    for x in enumerate(k):
        
        lst.append(x[1])
        
    return lst

#Multiples two elements by their numerical appearance
def multiplier(a, b, k):
    lst = lstmaker(k)
    return k.a_times_b_minus_c(lst[a],lst[b],0)

# %%
k.<a> = FiniteField(7**3)
k.multiplicative_generator()
# Out:
# a

# %%
for x in enumerate(k):
    print x
# Out:
# (0, 0)
# (1, a)
# (2, a^2)
# (3, a^2 + 3)
# (4, a^2 + 3*a + 3)
# (5, 4*a^2 + 3*a + 3)
# (6, 3*a + 5)
# (7, 3*a^2 + 5*a)
# (8, a^2 + 2)
# (9, a^2 + 2*a + 3)
# (10, 3*a^2 + 3*a + 3)
# (11, 6*a^2 + 3*a + 2)
# (12, 2*a^2 + 2*a + 4)
# (13, 4*a^2 + 4*a + 6)
# (14, a^2 + 6*a + 5)
# (15, 5*a + 3)
# (16, 5*a^2 + 3*a)
# (17, a^2 + 1)
# (18, a^2 + a + 3)
# (19, 2*a^2 + 3*a + 3)
# (20, 5*a^2 + 3*a + 6)
# (21, a^2 + 6*a + 1)
# (22, a + 3)
# (23, a^2 + 3*a)
# (24, 4*a^2 + 3)
# (25, 4*a^2 + 3*a + 5)
# (26, 5*a + 5)
# (27, 5*a^2 + 5*a)
# (28, 3*a^2 + 1)
# (29, 3*a^2 + a + 2)
# (30, 4*a^2 + 2*a + 2)
# (31, 6*a^2 + 2*a + 5)
# (32, a^2 + 5*a + 4)
# (33, 6*a^2 + 4*a + 3)
# (34, 3*a^2 + 3*a + 4)
# (35, 6*a^2 + 4*a + 2)
# (36, 3*a^2 + 2*a + 4)
# (37, 5*a^2 + 4*a + 2)
# (38, 2*a^2 + 2*a + 1)
# (39, 4*a^2 + a + 6)
# (40, 5*a^2 + 6*a + 5)
# (41, 4*a^2 + 5*a + 1)
# (42, 2*a^2 + a + 5)
# (43, 3*a^2 + 5*a + 6)
# (44, a^2 + 6*a + 2)
# (45, 2*a + 3)
# (46, 2*a^2 + 3*a)
# (47, 5*a^2 + 6)
# (48, 5*a^2 + 6*a + 1)
# ...

# %% [markdown]
# # Euclidean Algorithm

# %%
#Euclidean Algorithm

def gcd()

# %% [markdown]
# # Prime Field Case

# %%
#Checks for relative primality
def relativeprime(p, q):
